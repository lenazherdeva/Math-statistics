# %%
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Определим оценку

# %%
def estimate(sample, k): 
    s = np.arange(1, sample.size + 1) 
    return (math.factorial(k) * np.ones(sample.size) 
            / ((sample ** k).cumsum() / s) ) ** (k**(-1))

# %% [markdown]
# ### Сгенерируем выборку

# %%
N = 10**4
theta = 1

# %%
sample = sps.expon.rvs(size = N, scale= 1 / theta)

# %%
n = np.arange(1, N + 1)

# %% [markdown]
# ### График модуля разности оценки и истинного значения 𝜃 в зависимости от 𝑛 (𝑛 $\leq$ N)

# %%
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'pink', 'gold',
          'navy', 'springgreen', 'chocolate', 'aqua' ]
plt.figure(figsize=(15, 8))
plt.xlim((2000, N))  # размеры графика по горизонтальной оси 
plt.ylim((0, 0.25))  # размеры графика по вертикальной оси 
for k in range(12):
    plt.plot(n, abs(estimate(sample,k+1) - theta), color= colors[k], 
             linewidth=2.5, label= k + 1) 
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('N')
plt.ylabel('Estimate of the difference module')
plt.grid()  # сетка
plt.title(r'$\theta=$' + str(theta))

# %% [markdown]
# Исходя из графиков, для n стремящимся к N при 𝑘 = 1 значение модуля разности наименьшее (оценка ведет себя лучше всего)
